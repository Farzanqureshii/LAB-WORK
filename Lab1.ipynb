# %% [markdown]
# DISPLAY

# %%
print("121")
print("222")
# Out:
# 121
# 222

# %% [markdown]
# CALCULTOR

# %%
print("sum",1000+1)
print("minus",242-112)
print("quotient",121/12)
print("product",121*12)
# Out:
# sum 1001
# minus 130
# quotient 10.083333333333334
# product 1452

# %% [markdown]
# DISPLAY STRINGS

# %%
print("MY NAME IS FARZAN")
print("I AM FROM PAKISTAN")

# %% [markdown]
# INT DIVISOR AND REMAINDER

# %%
a=28;
b=14;
print("INT DIVISOR",a//b)
print("Remainder",a%b)
# Out:
# INT DIVISOR 2
# Remainder 0
